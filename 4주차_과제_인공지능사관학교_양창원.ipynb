# %% [markdown]
# <a href="https://colab.research.google.com/github/Shinest-changwon/Gwangju-AI/blob/master/4%EC%A3%BC%EC%B0%A8_%EA%B3%BC%EC%A0%9C_%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%EC%82%AC%EA%B4%80%ED%95%99%EA%B5%90_%EC%96%91%EC%B0%BD%EC%9B%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 4주차 과제
# - 용어 정리
# - 딥러닝 강의 클론 코딩
# - 딥러닝 순전파 & 역전파 계산

# %% [markdown]
# ## 1. 용어 정리
#
# 다음 제시된 단어의 정의(설명)를 정리하여 작성 하세요.
#
# * 2문장 이상 작성 해 주세요.
# * 주제(단어)와 크게 벗어나지만 않는다면 정답처리 됩니다.
# * 강의 뿐 아니라 기타 레퍼런스를 참고하여 작성하셔도 됩니다. (기타 레퍼런스를 참고하신 경우, 해당 레퍼런스를 정리하여 하단에 작성해 주세요.)

# %% [markdown]
# __(예시)__
# ### 심층 신경망
# : 입력층과 출력층 사이에 여러 개의 은닉층들로 이뤄진 인공신경망이다. 심층 신경망은 일반적으로 인공신경망과 마찬가지로 복잡한 비선형 관계들을 모델링 할 수 있다. 신층신경망의 목적은 분류 및 수치예측을 하기 위함이고 이미지 트레이닝이나 문자인식과 같은 분야에서 매우 유용하게 쓰이고 있다.

# %% [markdown]
# ### MCP 뉴런
# :AI의 설계를 위해 생물학적 뇌가 동작하는 방식을 이해하는 시도가 있었고, 1943년 워랜 맥컬록과 월터 피츠는 처음으로 간소화된 뇌의 뉴런 개념을 발표한다. 생물학적 뇌가 동작하는 방식을 알아보면 화학적, 전기적 신호를 처리하고 전달하는 뉴런이 있으며 이들은 뇌의 신경세포와 서로 연결되어 있다. 맥컬록과 피츠는 이러한 신경세포를 이진 출력을 내는 간단한 논리 회로로 표현다. 이를 맥컬록-피츠 뉴런(MuCulloch-Pitts Neuron, MCP)이라 한다.
#
# ### 퍼셉트론
# :1957년 프랭크 로젠 블랫은 MCP 뉴런 모델을 기반으로 퍼셉트론 학습 개념을 처음 발표한다. 프랭크 로젠 블렛은 퍼셉트론 규칙에서 자동으로 최적의 가중치를 학습하는 알고리즘을 제안한다. 이 가중치는 뉴런의 출력 신호를 낼지 말지를 결정하기 위해 입력 특성에 곱해지는 계수이다. 이러한 퍼셉트론은 입력을 받아서 계산 후 출력을 반환하는 간단한 구조로 나타낼 수 있는데 실제 신경망은 뉴런이 여러 개 모여 레이어를 구성한 후, 이 레이어가 다시 모여 구성된 형태이다. 하나의 뉴런을 자세히 보면 가중치와 활성화 함수가 숨어있다. 활성화 함수는 뉴런의 출력 값을 정하는 함수이며 가장 간단한 형태의 뉴런은 입력에 가중치를 곱한 뒤, 활성화 함수를 취하면 출력 값을 얻을 수 있다. 가중치는 처음에 초기화를 통해 무작위 값을 넣고, 학습 과정에서 점차 일정한 값으로 수렴하게 되어 원하는 출력에 가까워지게 된다.
#
# ### 역전파
# :역전파 알고리즘은 출력 값과 지도 데이터 사이에 생기는 '오차'를 이용해 출력층에서 입력층 쪽으로 가중치를 조정하는 것이다.
# 역전파가 세상에 나오게 된 계기는 퍼셉트론의 한계를 어느 정도 극복하기 위해서이다. 다층 퍼셉트론은 그저 단순 선형 분류기에 불과하다는 퍼셉트론의 한계를 어느 정도 극복하였으나, 파라미터 개수가 많아진다는 치명적인 약점이 있다. 역전파 알고리즘은 이 문제를 깔끔하게 해결하게 된다. 신경망의 지도 데이터와 출력 값 사이의 오차로 가중치를 조정해 원하는 출력값에 가까워질 수 있다.
#
# ### 강화학습
# :강화학습은 에이전트라는 존재가 환경과 상호작용하며, 이 환경에는 보상이라는 기준이 있어서 다양한 시행착오를 겪어가며 보상을 최대화하는 방향으로 학습을 진행하는 것이다. 그 중 순차적으로 계속 행동을 결정해야하는 문제를 수학적으로 정의한 것이 Markov Decision Process(MDP)이다.
#
#
# ### 과적합
# :머신러닝에서 학습 데이터를 과하게 학습하여 학습 데이터에서는 정확도가 높지만 실제 데이터에서는 오차가 발생하는 것을 뜻하는 용어이다. 목적함수의 매개변수의 차수를 늘리는 것이 이러한 과적합을 생기게 만든다. 결정 트리 학습에서는 정보이득이 최대가 되는 특성으로 데이터를 나누는데 계속해서 하다보면 이러한 과적합을 불러일으킬 수 있다. 그래서 일반적으로 트리의 최대 깊이를 제한하여 트리를 가지치기한다.
#
#
# ### 차원의 저주
# :머신러닝에서 고정된 크기의 훈련 데이터셋 차원이 늘어남에 따라 특성 공간이 점점 희소해 지는 현상을 말한다. 이러한 차원의 저주는 유클리디안 거리 측정 방식을 사용하는 알고리즘에 영향을 미친다. 이런 현상을 피하기 위해 올바른 변수의 선택, 차원 축소 기법, 표준화 등등 다양한 방법을 사용해야 한다.

# %% [markdown]
# ## 2. 딥러닝 강의 클론 코딩
#
# ####__퍼셉트론 구조 구현하기__
# 딥러닝 강의(__딥러닝 원리[1] 3:15 ~ 5:15 부분__)를 보고 코드를 따라 치며 출력 결과를 만드세요.
#
#
# * 하나의 코드셀에 해당 코드를 한번에 다 적어서 실행해주세요 (__그렇게 하지 않을 경우, 아래 이미지와 같은 출력값이 나오지 않을 수 있습니다__)
#
# *__주의!__ 실제로 코딩해서 출력해보면 강의에 나온 출력 결과와 다르게 나옵니다!!

# %% [markdown]
# ![대체 텍스트](https://www.notion.so/image/https%3A%2F%2Fs3-us-west-2.amazonaws.com%2Fsecure.notion-static.com%2F0cceeed0-0235-4b0f-af88-0b8c377d5b4b%2F_2020-06-09__9.35.23.png?table=block&id=88fd8912-9356-49a4-9fda-a1a63fe96ea9&width=2870&cache=v2)

# %%
import tensorflow as tf
tf.compat.v1.set_random_seed(2020)
x = 1
y = 0
w = tf.random.normal([1], 0, 1)

import math
def sigmoid(x):
    return 1/(1 + math.exp(-x))

output = sigmoid(x * w)
print(output) #출력
for i in range(1000):
    output = sigmoid(x * w)
    error = y - output
    w = w + x * 0.1 * error

    if i % 100 ==99:
        print("학습 횟수:", i, "Error:", error, "예측 결과:", output)
# Out:
# 0.47477188589261
# 학습 횟수: 99 Error: -0.10010598284299604 예측 결과: 0.10010598284299604
# 학습 횟수: 199 Error: -0.05178399422833116 예측 결과: 0.05178399422833116
# 학습 횟수: 299 Error: -0.034590451977903586 예측 결과: 0.034590451977903586
# 학습 횟수: 399 Error: -0.02588962752851373 예측 결과: 0.02588962752851373
# 학습 횟수: 499 Error: -0.020658699939863617 예측 결과: 0.020658699939863617
# 학습 횟수: 599 Error: -0.017174253993457355 예측 결과: 0.017174253993457355
# 학습 횟수: 699 Error: -0.014689506449480992 예측 결과: 0.014689506449480992
# 학습 횟수: 799 Error: -0.012829497265431342 예측 결과: 0.012829497265431342
# 학습 횟수: 899 Error: -0.011385568271837804 예측 결과: 0.011385568271837804
# 학습 횟수: 999 Error: -0.010232493309882492 예측 결과: 0.010232493309882492

# %% [markdown]
# ## 3. 딥러닝 순전파 & 역전파 계산
#
# 딥러닝 강의(__딥러닝 원리[2] 0:55 ~ 4:32 부분__)에 나오는 순전파 & 역전파 계산에 대한 문제 입니다.
#
# 해당 영상과 다음 이미지를 참고하여 다음 2가지 물음에 답하세요.
#
#
# (1) 학습률이 0.2 일 경우 출력층의 노드값
#
# (2) 학습률이 0.1과 0.2 중 기대출력값이 지도데이터 "3"과 더 가까운 학습률은?

# %% [markdown]
# ![대체 텍스트](https://www.notion.so/image/https%3A%2F%2Fs3-us-west-2.amazonaws.com%2Fsecure.notion-static.com%2Ff54dfd45-92ec-44ae-9616-6949d2484a45%2F_2020-06-10__5.22.03.png?table=block&id=ee05da89-3ceb-4ad9-a2d3-c9f68d24d1d9&width=3580&cache=v2)

# %% [markdown]
# ## (1) 학습률이 0.2 일 경우 출력층의 노드값 : 1.6
# ## (2) 학습률이 0.1과 0.2 중 기대출력값이 지도데이터 "3"과 더 가까운 학습률은? : 0.1
